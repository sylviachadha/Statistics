# %% [markdown]
# ## Random Variable

# %% [markdown]
# Definition-
#
# A variable whose value depends on the outcome of a Random phenomenon.<br>
# A Random Variable is characteristised by its distribution.

# %% [markdown]
# ### Combining Random Variables

# %% [markdown]
# Reference - https://www.khanacademy.org/math/ap-statistics/random-variables-ap/combining-random-variables/a/combining-random-variables-article

# %% [markdown]
# ### Types of Random Variables

# %% [markdown]
# ![Xnip2022-07-14_20-23-25.jpg](attachment:Xnip2022-07-14_20-23-25.jpg)
