# %% [markdown]
# # Statistical Concepts and Knowledge

# %% [markdown]
# # 1. Boxplot

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Five Number Summary

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - **Range** -> Maximum - Minimum
# - **IQR** -> Q3-Q1
# - Only in case of guassian/normal distribution the median is equal to mean.

# %% [markdown]
# # 2. Measures of Central Tendency - tell about center of data

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 3. Measures of Dispersion - tell about distance from center/amount of spread from center

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Mean Absolute Deviation (MAD) - http://www.alcula.com/calculators/statistics/mean-absolute-deviation/

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 4. Skew In Data

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 5. Levels of Measurement

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 6. Empirical Rule and Chebyshev's Inequality

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 7. Curtosis

# %% [markdown]
# The sharpness of the peak of a frequency-distribution curve.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 8. Covariance and Correlation

# %% [markdown]
# Covariance is dependent on scale of variable and have dimensions. Correlation is independent of scale of variable and dimensionless.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 9. Correlation Coefficient , r

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 10. Coefficient of determination/ (R squared) Equation

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Reference

# %% [markdown]
# https://www.scribbr.com/statistics/correlation-coefficient/
