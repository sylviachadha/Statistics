# %% [markdown]
# # Statistical Concepts and Knowledge

# %% [markdown]
# Purpose of Inferential Statistics is to do Hypothesis Testing.(Make an inference about population using sample via hypothesis testing).

# %% [markdown]
# # 1. Independent and Dependent Events in Probability

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 2. Addition Rule

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 3. Multiplication Rule

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 4. Permutation and Combination

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 5. Random Variable

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 6. Probability Distributions

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 7. Discrete Distributions

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Mean and Variance for Bernoulli, Binomial and Poisson Distribution as below-

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 8. Continuous Distributions

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 9. Empirical Rule of Normal Distribution

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 10. Central Limit Theoram

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 11. Confidence Interval

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 12. Hypothesis Testing Ho (Null) and Ha (alternate)

# %% [markdown]
# Since Hypothesis testing is done based on sample (to make inference about population) there may be errors in testing.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 13. Type 1 and Type 2 error which is alpha and beta

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 14. Confidence Interval and Power (1-alpha and 1-beta)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 15. Types of Hypothesis Tests

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 16. Hypothesis Tests for MEAN
#
# Z-test, T-test

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 17. Hypothesis Tests for Variance
#
# - Chi-square (One sample variance test) and F-test (2 sample variance test)
# - Application of Chi-square to check goodness of fit.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 18. Hypothesis Tests for Proportions
#
# P-Test

# %% [markdown]
# # 19. ANOVA

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Reference

# %% [markdown]
# https://www.varsitytutors.com/hotmath/hotmath_help/topics/normal-distribution-of-data

# %% [markdown]
# https://www.med.soton.ac.uk/stats_eLearning/confidencintervalsquiz/index.html
