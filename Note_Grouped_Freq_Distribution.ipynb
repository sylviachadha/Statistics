# %% [markdown]
# ## Grouped Data Frequency Distribution

# %% [markdown]
# Explaination for frequency distribution & calculating mode.<br>
# **Frequency distribution is a shorthand for a long list of numbers**
#
# https://www.youtube.com/watch?v=pQPAp7oZzVM

# %% [markdown]
# Mean for a frequency Distribution for a Discrete Variable
#
# https://www.youtube.com/watch?v=B5eIkwYLek8&t=133s

# %% [markdown]
# Median for a frequency Distribution for a Discrete Variable
#
# https://www.youtube.com/watch?v=GpTEXF3mx_c

# %% [markdown]
# ![Xnip2022-07-05_19-18-40.jpg](attachment:Xnip2022-07-05_19-18-40.jpg)
