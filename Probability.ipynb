# %% [markdown]
# ## Probability

# %% [markdown]
# Probability is based on random experiments.

# %% [markdown]
# ## Random Experiment

# %% [markdown]
# ![Xnip2022-05-21_07-45-46.jpg](attachment:Xnip2022-05-21_07-45-46.jpg)

# %% [markdown]
# ## Sample Space

# %% [markdown]
# ![Xnip2022-05-21_07-51-23.jpg](attachment:Xnip2022-05-21_07-51-23.jpg)

# %% [markdown]
# ## Event

# %% [markdown]
# Head and Tails are events in tossing of a coin.

# %% [markdown]
# ![Xnip2022-05-21_07-53-53.jpg](attachment:Xnip2022-05-21_07-53-53.jpg)

# %% [markdown]
# ## Mutually Exclusive Events

# %% [markdown]
# When u toss a coin one time you will get either a head or a tail. hence these are mutually exclusive, cannot occur at same time.
# So null set or impossible event i.e. impossible to get H and T simultaneously when u toss a coin.

# %% [markdown]
# ![Xnip2022-05-21_07-57-50.jpg](attachment:Xnip2022-05-21_07-57-50.jpg)
